# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from pandas import json_normalize
from random import randint
from time import sleep

# %%
secrets_file = open(".gitignore/secrets.txt","r")
string = secrets_file.read()
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
    return tracks

# %% [markdown]
# Lists of songs

# %%
playlist = sp.user_playlist_tracks("spotify", "1dhJtgwleWL9LToqQTqddH")

# %%
playlist['items'][1]
# Out:
# {'added_at': '2022-08-28T01:06:33Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/ha9ce21waia6br6bkybo3rznk'},
#   'href': 'https://api.spotify.com/v1/users/ha9ce21waia6br6bkybo3rznk',
#   'id': 'ha9ce21waia6br6bkybo3rznk',
#   'type': 'user',
#   'uri': 'spotify:user:ha9ce21waia6br6bkybo3rznk'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/88b20a4a339ecfe8a715525dfc941ba431d967aa?cid=f142e1b1b6014e9da5e1e861dccee2ec',
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'type': 'album',
#    'album_type': 'single',
#    'href': 'https://api.spotify.com/v1/albums/6u32goyaQHOcbbmdooLRJ4',
#    'id': '6u32goyaQHOcbbmdooLRJ4',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737a4e792526147b4291e54ce2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027a4e792526147b4291e54ce2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517a4e792526147b4291e54ce2',
#      'width': 64}],
#    'name': 'Grand',
#    'release_date': '2022-07-22',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:6u32goyaQHOcbbmdooLRJ4',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3oSJ7TBVCWMDMiYjXNiCKE'},
#      'href': 'https://api.spotify.com/v1/artists/3oSJ7TBVCWMDMiYjXNiCKE',
#      'id': '3oSJ7TBVCWMDMiYjXNiCKE',
#      'name': 'Kane Brown',
#      'type': 'artist',
#      'uri': 'spotify:artist:3oSJ7TBVCWMDMiYjXNiCKE'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6u32goyaQHOcbbmdooLRJ4'},
#    'total_tracks': 1},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3oSJ7TBVCWMDMiYjXNiCKE'},
#     'href': 'https://api.spotify.com/v1/artists/3oSJ7TBVCWMDMiYjXNiCKE',
#     'id': '3oSJ7TBVCWMDMiYjXNiCKE',
#     'name': 'Kane Brown',
#     'type': 'artist',
#     'uri': 'spotify:artist:3oSJ7TBVCWMDMiYjXNiCKE'}],
#   'disc_number': 1,
#   'track_number': 1,
#   'duration_ms': 178973,
#   'external_ids': {'isrc': 'USRN12200100'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4WZ3liyYz5ZzDcL4ibAuOi'},
#   'href': 'https://api.spotify.com/v1/tracks/4WZ3liyYz5ZzDcL4ibAuOi',
#   'id': '4WZ3liyYz5ZzDcL4ibAuOi',
#   'name': 'Grand',
#   'popularity': 49,
#   'uri': 'spotify:track:4WZ3liyYz5ZzDcL4ibAuOi',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist["total"]
# Out:
# 11000

# %%
all_tracks = get_playlist_tracks("1dhJtgwleWL9LToqQTqddH")
len(all_tracks)
# Out:
# 11000

# %%
tracks2 = json_normalize(all_tracks)
tracks2
# Out:
#                    added_at  is_local  ... video_thumbnail.url track
# 0      2022-10-06T15:58:53Z     False  ...                None   NaN
# 1      2022-08-28T01:06:33Z     False  ...                None   NaN
# 2      2022-07-28T15:05:18Z     False  ...                None   NaN
# 3      2022-07-13T15:10:41Z     False  ...                None   NaN
# 4      2022-03-31T19:44:21Z     False  ...                None   NaN
# ...                     ...       ...  ...                 ...   ...
# 10995  2022-09-08T16:05:17Z     False  ...                None   NaN
# 10996  2022-09-08T16:05:20Z     False  ...                None   NaN
# 10997  2022-09-08T16:05:21Z     False  ...                None   NaN
# 10998  2022-09-08T16:05:23Z     False  ...                None   NaN
# 10999  2022-09-08T16:05:24Z     False  ...                None   NaN
#
# [11000 rows x 41 columns]

# %%
print(tracks2['track.artists'])
# Out:
# 0        [{'external_urls': {'spotify': 'https://open.s...
# 1        [{'external_urls': {'spotify': 'https://open.s...
# 2        [{'external_urls': {'spotify': 'https://open.s...
# 3        [{'external_urls': {'spotify': 'https://open.s...
# 4        [{'external_urls': {'spotify': 'https://open.s...
#                                ...
# 10995    [{'external_urls': {'spotify': 'https://open.s...
# 10996    [{'external_urls': {'spotify': 'https://open.s...
# 10997    [{'external_urls': {'spotify': 'https://open.s...
# 10998    [{'external_urls': {'spotify': 'https://open.s...
# 10999    [{'external_urls': {'spotify': 'https://open.s...
# Name: track.artists, Length: 11000, dtype: object

# %%
"""
artists_df = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify','song_id', 'song_name', 'popularity' ])
for i in tracks2.index:
    artists_for_song = json_normalize(tracks2.iloc[i]['track.artists'])
    artists_for_song['song_id']    = tracks2.iloc[i]['track.id'] 
    artists_for_song['song_name']  = tracks2.iloc[i]['track.name']  
    artists_for_song['popularity'] = tracks2.iloc[i]['track.popularity'] 
    artists_df = pd.concat([artists_df, artists_for_song], axis=0)

"""
# Out:
# "\nartists_df = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri', 'external_urls.spotify','song_id', 'song_name', 'popularity' ])\nfor i in tracks2.index:\n    artists_for_song = json_normalize(tracks2.iloc[i]['track.artists'])\n    artists_for_song['song_id']    = tracks2.iloc[i]['track.id'] \n    artists_for_song['song_name']  = tracks2.iloc[i]['track.name']  \n    artists_for_song['popularity'] = tracks2.iloc[i]['track.popularity'] \n    artists_df = pd.concat([artists_df, artists_for_song], axis=0)\n\n"

# %%
artists_data_list = []

# Iterate over each index in tracks2
for i in tracks2.index:
    # Extract the list of artists for the current track
    artists_data = tracks2.iloc[i]['track.artists']
    
    # Check if 'artists_data' is a list
    if isinstance(artists_data, list):
        # Extract relevant information for each artist using list comprehension
        artists_info = [{
            'href': artist['href'],
            'id': artist['id'],
            'name': artist['name'],
            'type': artist['type'],
            'uri': artist['uri'],
            'external_urls.spotify': artist['external_urls']['spotify'],
            'song_id': tracks2.iloc[i]['track.id'],
            'song_name': tracks2.iloc[i]['track.name'],
            'popularity': tracks2.iloc[i]['track.popularity']
        } for artist in artists_data]
        
        # Extend artists_data_list with the extracted information
        artists_data_list.extend(artists_info)
    else:
        # Handle case where 'artists_data' is not a list (e.g., it's a float)
        # You may choose to skip this entry, log a warning, or handle it differently based on your requirements
        pass

# Convert the list of dictionaries to a DataFrame
artists_df = pd.DataFrame(artists_data_list)

# Display the resulting DataFrame
artists_df
# Out:
#                                                     href  ... popularity
# 0      https://api.spotify.com/v1/artists/6Cny0Wt5OKL...  ...       56.0
# 1      https://api.spotify.com/v1/artists/3oSJ7TBVCWM...  ...       49.0
# 2      https://api.spotify.com/v1/artists/3z97WMRi731...  ...       54.0
# 3      https://api.spotify.com/v1/artists/6lO3fSdhsdp...  ...       41.0
# 4      https://api.spotify.com/v1/artists/2VSHKHBTiXW...  ...       76.0
# ...                                                  ...  ...        ...
# 14286  https://api.spotify.com/v1/artists/0vC48gyflgf...  ...       64.0
# 14287  https://api.spotify.com/v1/artists/4DTbdShHu2R...  ...       64.0
# 14288  https://api.spotify.com/v1/artists/4mkEvoJAY8s...  ...       43.0
# 14289  https://api.spotify.com/v1/artists/6rADW3yvxPK...  ...       51.0
# 14290  https://api.spotify.com/v1/artists/6lDL8J1jfaq...  ...        8.0
#
# [14291 rows x 9 columns]

# %%
df_final = artists_df[['song_name', 'name', 'song_id', 'popularity']]
df_final
# Out:
#               song_name            name                 song_id  popularity
# 0      Die in This Town       The Seige  0bqrFwY1HixfnusFxhYbDl        56.0
# 1                 Grand      Kane Brown  4WZ3liyYz5ZzDcL4ibAuOi        49.0
# 2             Statement          NEFFEX  39kS4TwUw5yTJETWusq2VS        54.0
# 3           Wanchu Back      Aero Chord  3JIkZgwtTlbna1WEU9Qd5b        41.0
# 4               abcdefu           GAYLE  4fouWK6XVHhzl78KzQ1UjL        76.0
# ...                 ...             ...                     ...         ...
# 14286          Stronger         Slaydit  0iTI5FTB9iEUtcMdx9YyZS        64.0
# 14287          Stronger         Anjulie  0iTI5FTB9iEUtcMdx9YyZS        64.0
# 14288  No Money (Remix)            Vapi  233ZYmIrIy5Znu8T6vq2rc        43.0
# 14289     Lost In Sound        ROY KNOX  35LuknGQZ5kBbngf4tGSXg        51.0
# 14290          The Best  Future Royalty  3N1McBmL4FxqiHSfKAB413         8.0
#
# [14291 rows x 4 columns]

# %%
chunks = [(i, i+100) for i in range(0, len(df_final), 100)]
chunks
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# 14291

# %%
audio_features_df = json_normalize(audio_features_list)

# %%
audio_features_df.drop_duplicates(inplace=True)

# %%
df_w_audio_ft = pd.merge(left=df_final,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_w_audio_ft
# Out:
#               song_name         name  ... duration_ms  time_signature
# 0      Die in This Town    The Seige  ...    151500.0             4.0
# 1                 Grand   Kane Brown  ...    178973.0             4.0
# 2                 Grand   Kane Brown  ...    178973.0             4.0
# 3             Statement       NEFFEX  ...    186947.0             4.0
# 4             Statement       NEFFEX  ...    186947.0             4.0
# ...                 ...          ...  ...         ...             ...
# 14217  Crossed The Line  Linn Sandin  ...    147273.0             4.0
# 14218  Crossed The Line        Vosai  ...    147273.0             4.0
# 14219  Crossed The Line     Facading  ...    147273.0             4.0
# 14220  Crossed The Line  Linn Sandin  ...    147273.0             4.0
# 14221    Planeta Zombie    FIZIstyle  ...    153077.0             4.0
#
# [14222 rows x 22 columns]
